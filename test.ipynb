# %%
import pandas as pd

meta = pd.read_parquet('v2025_07_24f/metadata.parquet')
print(meta.columns)
print(meta.head())
# Out:
# Index(['window_id', 'label_code', 'pca_x', 'pca_y'], dtype='object')
#    window_id  label_code     pca_x     pca_y
# 0          0           1 -0.517380  0.149975
# 1          1           3 -1.355780  0.152169
# 2          2           1 -0.064726  0.201896
# 3          3           0  0.069965  0.146120
# 4          4           0  0.376337 -0.008487

# %%
import numpy as np

data = np.load('v2025_07_24f/windows.npz')
print(data.files)
for k in data.files:
    print(f"{k}: shape={data[k].shape}, dtype={data[k].dtype}")
# Out:
# ['traces', 'label_seq', 'encoded_labels', 'emb_mean', 'pca_xy', 'origin_keys']
# traces: shape=(32754, 500), dtype=float32
# label_seq: shape=(32754, 2, 500), dtype=uint8
# encoded_labels: shape=(32754,), dtype=uint8
# emb_mean: shape=(32754, 64), dtype=float32
# pca_xy: shape=(32754, 2), dtype=float32
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 print(data.files)
#       5 for k in data.files:
# ----> 6     print(f"{k}: shape={data[k].shape}, dtype={data[k].dtype}")
#
# File ~/miniconda3/envs/llm/lib/python3.11/site-packages/numpy/lib/npyio.py:256, in NpzFile.__getitem__(self, key)
#     254 if magic == format.MAGIC_PREFIX:
#     255     bytes = self.zip.open(key)
# --> 256     return format.read_array(bytes,
#     257                              allow_pickle=self.allow_pickle,
# ...
